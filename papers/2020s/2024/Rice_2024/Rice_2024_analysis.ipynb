# %% [markdown]
# # Co-option of the trichome-forming network initiated the evolution of a morphological novelty in Drosophila eugracilis
# Analysis notebook for Rice_2024
#
# **Citation:** Gavin Rice, Tatiana Gaitan-Escudero, Kenechukwu Charles-Obi, Julia Zeitlinger, Mark Rebeiz. (2024). [Co-option of the trichome-forming network initiated the evolution of a morphological novelty in Drosophila eugracilis](10.1016/j.cub.2024.09.073). Current Biology.
#
# ## Sections
# - ### 1. Summary
# - ### 2. Data
# - ### 3. Analysis
# - ### 4. Notes

# %% [markdown]
# ## 1. Summary
# Provide a brief summary of the paper here.

# %%
## 2. Data
# Import necessary packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your data here, e.g.:
# df = pd.read_csv('your_dataset.csv')
# df.head()

# %% [markdown]
# ## 3. Analysis
# Reproduce figures and analyses from the paper here.

# %%
# Example plotting template
# sns.set(style='whitegrid')
# plt.figure(figsize=(8,6))
# sns.lineplot(data=df, x='X_column', y='Y_column')
# plt.show()

# %% [markdown]
# ## 4. Notes
# Add observations, insights, or future ideas here.
